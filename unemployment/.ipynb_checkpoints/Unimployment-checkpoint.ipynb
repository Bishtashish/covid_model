# %%
import pandas as pd
import numpy as np
import matplotlib.style as style
import matplotlib.pylab as plt
import seaborn as sns
import random
import scipy.stats as stats
# %matplotlib inline 
sns.set()

# %%
# educ = pd.read_excel('educ2_week16.xlsx',sheet_name='NC')

cur = pd.read_csv('BLS/Current.txt','\t')
hires = pd.read_csv('BLS/Hires.txt','\t')
jobOpenings = pd.read_csv('BLS/JobOpenings.txt','\t')
layOff = pd.read_csv('BLS/LayoffsDischarges.txt','\t')
quits = pd.read_csv('BLS/Quits.txt','\t')
other = pd.read_csv('BLS/OtherSeparations.txt','\t')
totalSep = pd.read_csv('BLS/totalSeparations.txt','\t')

# %%
cur.dtypes
# Out:
# series_id                          object
# year                                int64
# period                             object
#        value                      float64
# footnote_codes                     object
# dtype: object

# %%
hires
# Out:
#        series_id                       year period         value  \
# 0      JTS000000000000000HIL           2000    M12        5426.0
# 1      JTS000000000000000HIL           2001    M01        5722.0
# 2      JTS000000000000000HIL           2001    M02        5303.0
# 3      JTS000000000000000HIL           2001    M03        5528.0
# 4      JTS000000000000000HIL           2001    M04        5204.0
# ...                               ...   ...    ...           ...
# 37387  JTU929000000000000HIR           2020    M05           1.6
# 37388  JTU929000000000000HIR           2020    M06           2.3
# 37389  JTU929000000000000HIR           2020    M07           1.8
# 37390  JTU929000000000000HIR           2020    M08           1.5
# 37391  JTU929000000000000HIR           2020    M09           1.5
#
#       footnote_codes
# 0                NaN
# 1                NaN
# 2                NaN
# 3                NaN
# 4                NaN
# ...              ...
# 37387            NaN
# 37388            NaN
# 37389            NaN
# 37390            NaN
# 37391              P
#
# [37392 rows x 5 columns]

# %%
# cur['current']=cur['value']
cur.columns = cur.columns.str.replace(" ","")
cur.rename(columns ={'value':'current'}, inplace=True)
cur = cur.astype({"year": str, "period": str})
cur.year = cur.year.apply(lambda x: x.lstrip().replace(" ",""))
cur.period = cur.period.apply(lambda x: x.lstrip().replace(" ",""))
cur = cur.drop_duplicates(subset=['year','period'], keep='last')

cur.dtypes
# Out:
# series_id          object
# year               object
# period             object
# current           float64
# footnote_codes     object
# dtype: object

# %%
style.use('ggplot')
plt.figure(figsize=(15,4))
# plt.plot(cur['year'],cur['current'])
# sns.countplot(x='year',data=cur, palette="OrRd")
plt.bar(cur['year'],cur['current'])
plt.xticks(range(1,14))
plt.xlabel('Year')
plt.grid(True)
plt.ylabel('Current employment in millions')
plt.title('Effect of COVID-19 on current employment')
# Out:
# Text(0.5, 1.0, 'Effect of COVID-19 on current employment')

# %%
hires.columns = hires.columns.str.replace(" ","")
hires.rename(columns ={'value':'hired'}, inplace=True)
hires = hires.astype({"year": str, "period": str})
hires.year = hires.year.apply(lambda x: x.lstrip().replace(" ",""))
hires.period = hires.period.apply(lambda x: x.lstrip().replace(" ",""))
hires = hires.drop_duplicates(subset=['year','period'], keep='last')

# %%
style.use('ggplot')
plt.figure(figsize=(15,4))
plt.bar(hires['year'],hires['hired'])
plt.xticks(range(1,22))
plt.xlabel('Year')
plt.grid(True)
plt.ylabel('Total hirinh in million ')
plt.title('Effect of COVID-19 on Hiring')
# Out:
# Text(0.5, 1.0, 'Effect of COVID-19 on Hiring')

# %%
jobOpenings.columns = jobOpenings.columns.str.replace(" ","")
jobOpenings.rename(columns ={'value':'jobOpening'}, inplace=True)
jobOpenings = jobOpenings.astype({"year": str, "period": str})
jobOpenings.year = jobOpenings.year.apply(lambda x: x.lstrip().replace(" ",""))
jobOpenings.period = jobOpenings.period.apply(lambda x: x.lstrip().replace(" ",""))
jobOpenings = jobOpenings.drop_duplicates(subset=['year','period'], keep='last')

# %%
style.use('ggplot')
plt.figure(figsize=(15,4))
plt.bar(jobOpenings['year'],jobOpenings['jobOpening'])
plt.xticks(range(1,21))
plt.xlabel('Year')
plt.grid(True)
plt.ylabel('Total Ipening in million ')
plt.title('Effect of COVID-19 on Job Openings')
# Out:
# Text(0.5, 1.0, 'Effect of COVID-19 on Job Openings')

# %%
layOff.columns = layOff.columns.str.replace(" ","")
layOff.rename(columns ={'value':'layOff'}, inplace=True)
layOff = layOff.astype({"year": str, "period": str})
layOff.year = layOff.year.apply(lambda x: x.lstrip().replace(" ",""))
layOff.period = layOff.period.apply(lambda x: x.lstrip().replace(" ",""))
layOff = layOff.drop_duplicates(subset=['year','period'], keep='last')

# %%
style.use('ggplot')
plt.figure(figsize=(15,4))
plt.bar(layOff['year'],layOff['layOff'])
plt.xticks(range(1,20))
plt.xlabel('Year')
plt.grid(True)
plt.ylabel('Total LayOff in million ')
plt.title('Effect of COVID-19 on LayOffs')
# Out:
# Text(0.5, 1.0, 'Effect of COVID-19 on LayOffs')

# %%
quits.columns = quits.columns.str.replace(" ","")
quits.rename(columns ={'value':'quits'}, inplace=True)
quits = quits.astype({"year": str, "period": str})
quits.year = quits.year.apply(lambda x: x.lstrip().replace(" ",""))
quits.period = quits.period.apply(lambda x: x.lstrip().replace(" ",""))
quits = quits.drop_duplicates(subset=['year','period'], keep='last')

# %%
style.use('ggplot')
plt.figure(figsize=(15,4))
plt.bar(quits['year'],quits['quits'])
plt.xticks(range(1,22))
plt.xlabel('Year')
plt.grid(True)
plt.ylabel('Total quits in million ')
plt.title('Quits in market due to COVID-19 ')
# Out:
# Text(0.5, 1.0, 'Quits in market due to COVID-19 ')

# %%
other.columns = other.columns.str.replace(" ","")
other.rename(columns ={'value':'other'}, inplace=True)
other = other.astype({"year": str, "period": str})
other.year = other.year.apply(lambda x: x.lstrip().replace(" ",""))
other.period = other.period.apply(lambda x: x.lstrip().replace(" ",""))
other = other.drop_duplicates(subset=['year','period'], keep='last')

# %%
style.use('ggplot')
plt.figure(figsize=(15,4))
plt.bar(other['year'],other['other'])
plt.xticks(range(1,20))
plt.xlabel('Year')
plt.grid(True)
plt.ylabel('Other Seperation in million ')
plt.title('People left due to other reasons')
# Out:
# Text(0.5, 1.0, 'People left due to other reasons')

# %%
totalSep.columns = totalSep.columns.str.replace(" ","")
totalSep.rename(columns ={'value':'totalSeperations'}, inplace=True)
totalSep = totalSep.astype({"year": str, "period": str})
totalSep.year = totalSep.year.apply(lambda x: x.lstrip().replace(" ",""))
totalSep.period = totalSep.period.apply(lambda x: x.lstrip().replace(" ",""))
totalSep = totalSep.drop_duplicates(subset=['year','period'], keep='last')

# unimployed = cur[['year','period','current']]

# %%
style.use('ggplot')
plt.figure(figsize=(15,4))
plt.bar(totalSep['year'],totalSep['totalSeperations'])
plt.xticks(range(1,22))
plt.xlabel('Year')
plt.grid(True)
plt.ylabel('Total Seperation in million')
plt.title('Total Seperation')
# Out:
# Text(0.5, 1.0, 'Total Seperation')

# %%
# unimployed = cur[['year','period','current']]
# cur_hire = cur.append(hires, sort=False)
# cur_hire = pd.merge(cur, hires[['year','period','hired']], on=['year','period'], right_index=True,
#       how='left', sort=False)
cur_hire = pd.merge(cur[['year','period','current']], hires[['year','period','hired']], on=['year','period'], how='outer', validate="one_to_one")
cur_hire
# Out:
#      year period  current  hired
# 0    2011    M01      1.1    0.9
# 1    2011    M02      0.9    0.8
# 2    2011    M03      1.0    0.9
# 3    2011    M04      1.1    1.2
# 4    2011    M05      1.2    1.8
# ..    ...    ...      ...    ...
# 252  2010    M09      NaN    1.0
# 253  2010    M10      NaN    1.0
# 254  2010    M11      NaN    1.0
# 255  2010    M12      NaN    0.8
# 256  2010    M13      NaN   14.6
#
# [257 rows x 4 columns]

# %%
df = cur_hire.groupby(['year']).sum()
df = df.reset_index()
df.plot(x="year", y=["current", "hired"], kind="bar", figsize=(20,6))

plt.show()

# %%
hires.describe(include="all")
# Out:
#                              series_id  year period       hired footnote_codes
# count                              257   257    257  257.000000              1
# unique                               1    21     13         NaN              1
# top     JTU929000000000000HIR           2003    M03         NaN              P
# freq                               257    13     20         NaN              1
# mean                               NaN   NaN    NaN    2.836576            NaN
# std                                NaN   NaN    NaN    4.578472            NaN
# min                                NaN   NaN    NaN    0.700000            NaN
# 25%                                NaN   NaN    NaN    1.200000            NaN
# 50%                                NaN   NaN    NaN    1.500000            NaN
# 75%                                NaN   NaN    NaN    2.000000            NaN
# max                                NaN   NaN    NaN   21.500000            NaN

# %%
job_lay = pd.merge(jobOpenings[['year','period','jobOpening']], layOff[['year','period','layOff']], on=['year','period'], how='outer', validate="one_to_one")

# %%
df = job_lay.groupby(['year']).sum()
df = df.reset_index()
df.plot(x="year", y=["jobOpening", "layOff"], kind="bar", figsize=(20,6))

plt.show()

# %%
# mask = unimployed['year']==hires['year'] and unimployed['period']==hires['period']

quit_other = pd.merge(quits[['year','period','quits']], other[['year','period','other']], on=['year','period'], how='outer', validate="one_to_one")

# %%
quit_other_total = pd.merge(quit_other[['year','period','quits','other']], totalSep[['year','period','totalSeperations']], on=['year','period'], how='outer', validate="one_to_one")

# %%
df = quit_other_total.groupby(['year']).sum()
df = df.reset_index()
df.plot(x="year", y=["quits", "other","totalSeperations"], kind="bar", figsize=(25,6))

plt.show()

# %%
one =  pd.merge(cur_hire[['year','period','current','hired']], job_lay[['year','period','jobOpening','layOff']], on=['year','period'], how='outer', validate="one_to_one")

final_unimployment = pd.merge(one[['year','period','jobOpening','current','hired','layOff']], quit_other_total[['year','period','quits','other','totalSeperations']], on=['year','period'], how='outer', validate="one_to_one")

# %%
# final_unimployment
# group = final_unimployment['year'].unique()
# group = list(map(int, group))
# group = sorted(group)
df = final_unimployment.groupby(['year']).sum()
df = df.reset_index()
df.plot(x="year", y=["quits", "other","layOff","totalSeperations","jobOpening","current","hired"], kind="bar", figsize=(28,10))

plt.show()

# %%
import seaborn as sns
# %matplotlib inline

# %%
final_unimployment.info(verbose=True)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 257 entries, 0 to 256
# Data columns (total 9 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   year              257 non-null    object
#  1   period            257 non-null    object
#  2   jobOpening        238 non-null    float64
#  3   current           126 non-null    float64
#  4   hired             257 non-null    float64
#  5   layOff            257 non-null    float64
#  6   quits             257 non-null    float64
#  7   other             257 non-null    float64
#  8   totalSeperations  257 non-null    float64
# dtypes: float64(7), object(2)
# memory usage: 20.1+ KB

# %%
final_unimployment.describe(percentiles=[0.1,0.25,0.5,0.75,0.9])
# Out:
#        jobOpening     current       hired      layOff       quits       other  \
# count  238.000000  126.000000  257.000000  257.000000  257.000000  257.000000
# mean     2.672689    2.806349    2.836576    1.005837    1.293774    0.485603
# std      0.620849    4.513814    4.578472    1.643882    2.098353    0.774588
# min      1.500000    0.900000    0.700000    0.200000    0.400000    0.100000
# 10%      1.900000    1.200000    1.000000    0.300000    0.500000    0.200000
# 25%      2.200000    1.300000    1.200000    0.300000    0.600000    0.200000
# 50%      2.600000    1.500000    1.500000    0.500000    0.700000    0.300000
# 75%      3.000000    1.800000    2.000000    0.700000    0.800000    0.300000
# 90%      3.600000    2.650000    2.800000    1.340000    1.200000    0.400000
# max      4.200000   20.700000   21.500000    8.000000   10.600000    3.900000
#
#        totalSeperations
# count        257.000000
# mean           2.784825
# std            4.471424
# min            0.900000
# 10%            1.100000
# 25%            1.300000
# 50%            1.400000
# 75%            1.700000
# 90%            2.600000
# max           20.700000

# %%
final_unimployment.columns
# Out:
# Index(['year', 'period', 'jobOpening', 'current', 'hired', 'layOff', 'quits',
#        'other', 'totalSeperations'],
#       dtype='object')

# %%
sns.pairplot(final_unimployment)

# %% [markdown]
# Correlation Matrix and Heatmap

# %%
final_unimployment.corr()
# Out:
#                   jobOpening   current     hired    layOff     quits  \
# jobOpening          1.000000  0.162153  0.284460 -0.057663  0.405307
# current             0.162153  1.000000  0.990899  0.988925  0.993626
# hired               0.284460  0.990899  1.000000  0.960924  0.991824
# layOff             -0.057663  0.988925  0.960924  1.000000  0.960366
# quits               0.405307  0.993626  0.991824  0.960366  1.000000
# other               0.020505  0.987670  0.978410  0.964563  0.974128
# totalSeperations    0.139594  1.000000  0.989240  0.986335  0.992095
#
#                      other  totalSeperations
# jobOpening        0.020505          0.139594
# current           0.987670          1.000000
# hired             0.978410          0.989240
# layOff            0.964563          0.986335
# quits             0.974128          0.992095
# other             1.000000          0.985479
# totalSeperations  0.985479          1.000000

# %%
plt.figure(figsize=(10,7))
sns.heatmap(final_unimployment.corr(),annot=True,linewidths=2)

# %%
def correlation_matrix(df):
    from matplotlib import pyplot as plt
    from matplotlib import cm as cm

    fig = plt.figure(figsize=(16,12))
    ax1 = fig.add_subplot(111)
    cmap = cm.get_cmap('jet', 30)
    cax = ax1.imshow(final_unimployment.corr(), interpolation="nearest", cmap=cmap)
    ax1.grid(True)
    plt.title('Unemployment data features correlation\n',fontsize=15)
    labels=df.columns
    ax1.set_xticklabels(labels,fontsize=9)
    ax1.set_yticklabels(labels,fontsize=9)
    # Add colorbar, make sure to specify tick locations to match desired ticklabels
    fig.colorbar(cax, ticks=[0.1*i for i in range(-11,11)])
    plt.show()

correlation_matrix(final_unimployment)

# %%
pip install pmdarima
# Out:
# Requirement already satisfied: pmdarima in /Users/aakankshachauhan/opt/anaconda3/lib/python3.7/site-packages (1.8.0)
# Requirement already satisfied: setuptools!=50.0.0,>=38.6.0 in /Users/aakankshachauhan/opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (46.0.0.post20200309)
# Requirement already satisfied: statsmodels!=0.12.0,>=0.11 in /Users/aakankshachauhan/opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (0.11.0)
# Requirement already satisfied: scikit-learn>=0.22 in /Users/aakankshachauhan/opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (0.22.1)
# Requirement already satisfied: urllib3 in /Users/aakankshachauhan/opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (1.25.8)
# Requirement already satisfied: joblib>=0.11 in /Users/aakankshachauhan/opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (0.14.1)
# Requirement already satisfied: numpy>=1.17.3 in /Users/aakankshachauhan/opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (1.18.1)
# Requirement already satisfied: scipy>=1.3.2 in /Users/aakankshachauhan/opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (1.4.1)
# Requirement already satisfied: pandas>=0.19 in /Users/aakankshachauhan/opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (1.0.5)
# Requirement already satisfied: Cython<0.29.18,>=0.29 in /Users/aakankshachauhan/opt/anaconda3/lib/python3.7/site-packages (from pmdarima) (0.29.15)
# Requirement already satisfied: python-dateutil>=2.6.1 in /Users/aakankshachauhan/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.19->pmdarima) (2.8.1)
# Requirement already satisfied: pytz>=2017.2 in /Users/aakankshachauhan/opt/anaconda3/lib/python3.7/site-packages (from pandas>=0.19->pmdarima) (2019.3)
# Requirement already satisfied: six>=1.5 in /Users/aakankshachauhan/opt/anaconda3/lib/python3.7/site-packages (from python-dateutil>=2.6.1->pandas>=0.19->pmdarima) (1.14.0)
# Requirement already satisfied: patsy>=0.5 in /Users/aakankshachauhan/opt/anaconda3/lib/python3.7/site-packages (from statsmodels!=0.12.0,>=0.11->pmdarima) (0.5.1)
# Note: you may need to restart the kernel to use updated packages.

# %%
from statsmodels.tsa.arima_model import ARIMA

import pmdarima as pm

model = pm.auto_arima(final_unimployment.layOff, start_p=1, start_q=1,
                      test='adf',       # use adftest to find optimal 'd'
                      max_p=3, max_q=3, # maximum p and q
                      m=1,              # frequency of series
                      d=None,           # let model determine 'd'
                      seasonal=False,   # No Seasonality
                      start_P=0, 
                      D=0, 
                      trace=True,
                      error_action='ignore',  
                      suppress_warnings=True, 
                      stepwise=True)

print(model.summary())
# Out:
# Performing stepwise search to minimize aic
#  ARIMA(1,0,1)(0,0,0)[0]             : AIC=inf, Time=0.20 sec
#  ARIMA(0,0,0)(0,0,0)[0]             : AIC=1067.822, Time=0.01 sec
#  ARIMA(1,0,0)(0,0,0)[0]             : AIC=1058.793, Time=0.02 sec
#  ARIMA(0,0,1)(0,0,0)[0]             : AIC=1061.347, Time=0.02 sec
#  ARIMA(2,0,0)(0,0,0)[0]             : AIC=1054.884, Time=0.02 sec
#  ARIMA(3,0,0)(0,0,0)[0]             : AIC=1050.968, Time=0.03 sec
#  ARIMA(3,0,1)(0,0,0)[0]             : AIC=inf, Time=0.29 sec
#  ARIMA(2,0,1)(0,0,0)[0]             : AIC=inf, Time=0.21 sec
#  ARIMA(3,0,0)(0,0,0)[0] intercept   : AIC=983.375, Time=0.08 sec
#  ARIMA(2,0,0)(0,0,0)[0] intercept   : AIC=985.221, Time=0.05 sec
#  ARIMA(3,0,1)(0,0,0)[0] intercept   : AIC=964.404, Time=0.30 sec
#  ARIMA(2,0,1)(0,0,0)[0] intercept   : AIC=975.918, Time=0.12 sec
#  ARIMA(3,0,2)(0,0,0)[0] intercept   : AIC=958.079, Time=0.36 sec
#  ARIMA(2,0,2)(0,0,0)[0] intercept   : AIC=952.310, Time=0.35 sec
#  ARIMA(1,0,2)(0,0,0)[0] intercept   : AIC=963.002, Time=0.28 sec
#  ARIMA(2,0,3)(0,0,0)[0] intercept   : AIC=962.182, Time=0.36 sec
#  ARIMA(1,0,1)(0,0,0)[0] intercept   : AIC=980.694, Time=0.11 sec
#  ARIMA(1,0,3)(0,0,0)[0] intercept   : AIC=973.540, Time=0.18 sec
#  ARIMA(3,0,3)(0,0,0)[0] intercept   : AIC=956.404, Time=0.49 sec
#  ARIMA(2,0,2)(0,0,0)[0]             : AIC=inf, Time=0.35 sec
#
# Best model:  ARIMA(2,0,2)(0,0,0)[0] intercept
# Total fit time: 3.876 seconds
#                                SARIMAX Results
# ==============================================================================
# Dep. Variable:                      y   No. Observations:                  257
# Model:               SARIMAX(2, 0, 2)   Log Likelihood                -470.155
# Date:                Wed, 16 Dec 2020   AIC                            952.310
# Time:                        19:11:05   BIC                            973.604
# Sample:                             0   HQIC                           960.873
#                                 - 257
# Covariance Type:                  opg
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# intercept      1.6806      0.390      4.312      0.000       0.917       2.444
# ar.L1          0.2861      0.038      7.499      0.000       0.211       0.361
# ar.L2         -0.9583      0.033    -28.843      0.000      -1.023      -0.893
# ma.L1         -0.4120      0.021    -19.507      0.000      -0.453      -0.371
# ma.L2          0.9787      0.025     39.364      0.000       0.930       1.027
# sigma2         2.2428      0.210     10.697      0.000       1.832       2.654
# ===================================================================================
# Ljung-Box (Q):                      573.26   Jarque-Bera (JB):               683.82
# Prob(Q):                              0.00   Prob(JB):                         0.00
# Heteroskedasticity (H):               1.24   Skew:                             2.52
# Prob(H) (two-sided):                  0.33   Kurtosis:                         9.21
# ===================================================================================
#
# Warnings:
# [1] Covariance matrix calculated using the outer product of gradients (complex-step).

# %%
model.plot_diagnostics(figsize=(15,12))
plt.show()

# %%
n_periods = 24
fc, confint = model.predict(n_periods=n_periods, return_conf_int=True)
index_of_fc = np.arange(len(final_unimployment.layOff), len(final_unimployment.layOff)+n_periods)

# make series for plotting purpose
fc_series = pd.Series(fc, index=index_of_fc)
lower_series = pd.Series(confint[:, 0], index=index_of_fc)
upper_series = pd.Series(confint[:, 1], index=index_of_fc)

# Plot
plt.figure(figsize=(15,4))
plt.plot(final_unimployment.layOff)
plt.plot(fc_series, color='darkgreen')
plt.fill_between(lower_series.index, 
                 lower_series, 
                 upper_series, 
                 color='k', alpha=.15)

plt.title("Final Forecast of Usage")
plt.show()
